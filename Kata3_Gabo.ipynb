# %% [markdown]
# # Ejercicio - Escribir declaraciones if, else, y elif

# %%
# Añadir el código necesario para crear una variable que guarde la velocidad del asteroide.
# Escribe una expresión de prueba para calcular si necesita una advertencia.
# Agregue las instrucciones que se ejecutarán si la expresión de prueba es true o false.

vasteroide = 0

vasteroide = input("¿Cual es la velocidad del asteroide?: ")

if int(vasteroide)>25:
    print("Alerta! - Se aproxima un asteroide a ", str(vasteroide),"km/h")
else:
    print("Ningun asteroide con velocidad para alertar")
    print("Ultimo asteroide detectado con velocidad de ", str(vasteroide), "km/h")
# Out:
# Alerta! - Se aproxima un asteroide a  80 km/h

# %%
# Agrega el código para crear una variable para un asteroide que viaja a 19 km/s
# Escribe varias expresiones de prueba para determinar si puedes ver el rayo de luz desde la tierra
# Agrega las instrucciones que se ejecutarán si las expresiones de prueba son True o False

vasteroide = input("¿A que velocidad viaja el asteroide?")
if int(vasteroide) >= 20:
    rluz = input("Busca en el cielo, ¿Puedes ver un rayo de luz?")
    if rluz == "SI" or rluz == "Si" or rluz == "si":
        print("Disfruta del evento, recuerda que si un asteroide entra en la atmósfera de la Tierra a una velocidad mayor o igual a 20 km/s, regularmente podras ver un rayo de luz")
    else:
        print("Busca bien porque regularmente deberias ver un rayo de luz")
else:
    print("Asteroide demasiado lento, no es posible verlo desde la Tierra")
# Out:
# Disfruta del evento, recuerda que si un asteroide entra en la atmósfera de la Tierra a una velocidad mayor o igual a 20 km/s, regularmente podras ver un rayo de luz

# %%
# Agrega el código para crear nuevas variables para la velocidad y el tamaño del asteroide
# Para probar el código, prueba con varias velocidades y tamaños
# Escribe varias expresiones de prueba o combinaciones de expresiones de prueba para determinar qué mensaje se debe enviar a Tierra.

vasteroide = input("¿A que velocidad viaja el asteroide?")
tasteroide = input("¿De que tamaño es el asteroide?")

if int(vasteroide) > 25 and int(tasteroide) > 25:
    print("Alerta! - Se aproxima un asteroide a ", str(vasteroide),"km/h")
    print("Alerta! - De un tamaño superior a ", str(tasteroide),"metros" )
elif int(vasteroide) >= 20:
    rluz = input("Busca en el cielo, ¿Puedes ver un rayo de luz?")
    if rluz == "SI" or rluz == "Si" or rluz == "si":
        print("Disfruta del evento, recuerda que si un asteroide entra en la atmósfera de la Tierra a una velocidad mayor o igual a 20 km/s, regularmente podras ver un rayo de luz")
    else:
        print("Busca bien porque regularmente deberias ver un rayo de luz")
elif int(tasteroide) < 25:
    print("Asteroide demasiado lento, no es posible verlo desde la Tierra")
    print("Ultimo asteroide detectado con velocidad de ", str(vasteroide), "km/h")
    print("y de un tamaño de", str(tasteroide), "metros")
else:
    print("Asteroide demasiado lento, no es posible verlo desde la Tierra")
    print("Ultimo asteroide detectado con velocidad de ", str(vasteroide), "km/h")
    print("y de un tamaño de", str(tasteroide), "metros")
# Out:
# Alerta! - Se aproxima un asteroide a  30 km/h
# Alerta! - De un tamaño superior a  90 metros
