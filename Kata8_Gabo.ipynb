# %% [markdown]
# # Ejercicio 1: Creación de diccionarios de Python

# %%
# Crea un diccionario llamado planet con los datos propuestos

planet = {
    'name': 'Marte',
    'moons': 2
}

# %%
# Muestra el nombre del planeta y el número de lunas que tiene.

print(f'{planet["name"]} tiene {planet["moons"]} luna')
# Out:
# Marte tiene 2 luna

# %%
# Agrega la clave circunferencia con los datos proporcionados previamente

planet['circunferencia (km)'] = {
    'Fobos': 70,
    'Deimos': 39
}

print(planet)
# Out:
# {'name': 'Marte', 'moons': 2, 'circunferencia (km)': {'Fobos': 70, 'Deimos': 39}}

# %%
# Imprime el nombre del planeta con su circunferencia polar.

print(f'Las lunas de {planet["name"]} tienen la siguiente circunferencia {planet["circunferencia (km)"]}')
# Out:
# Las lunas de Marte tienen la siguiente circunferencia {'Fobos': 70, 'Deimos': 39}

# %%
# Añade el código para determinar el número de lunas.

# Obtenemos la lista de las lunas
# Almacenamos los resultados en una variable moons
moons = planet.values()
print(moons)

# Obtenemos el total de planetas
# Almacenamos los resultados en una variable llamada years
years = len(planet.keys())
print(years)
# Out:
# dict_values(['Marte', 2, {'Fobos': 70, 'Deimos': 39}])
# 3

# %%
# Calcula el total_moons agregando todas las lunas
# Almacena su valor en una variable llamada total_moons

total_moons = 0

for total_moons in years:
    total_moons = total_moons + years

# Calcula el promedio dividiendo el total_moons por el número de planetas
promedio = total_moons / planets

# Muestra el promedio
print(promedio)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/gabo.cruz/Documents/GitHub/InnovaccionLaunchX/Kata8_Gabo.ipynb Cell 7' in <module>
#       <a href='vscode-notebook-cell:/Users/gabo.cruz/Documents/GitHub/InnovaccionLaunchX/Kata8_Gabo.ipynb#ch0000025?line=0'>1</a> # Calcula el total_moons agregando todas las lunas
#       <a href='vscode-notebook-cell:/Users/gabo.cruz/Documents/GitHub/InnovaccionLaunchX/Kata8_Gabo.ipynb#ch0000025?line=1'>2</a> # Almacena su valor en una variable llamada total_moons
#       <a href='vscode-notebook-cell:/Users/gabo.cruz/Documents/GitHub/InnovaccionLaunchX/Kata8_Gabo.ipynb#ch0000025?line=3'>4</a> total_moons = 0
# ----> <a href='vscode-notebook-cell:/Users/gabo.cruz/Documents/GitHub/InnovaccionLaunchX/Kata8_Gabo.ipynb#ch0000025?line=5'>6</a> for total_moons in years:
# ...
